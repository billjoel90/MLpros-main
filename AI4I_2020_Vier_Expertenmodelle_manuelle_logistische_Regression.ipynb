# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("ai4i2020.csv")
features = df[['Air temperature [K]', 
               'Process temperature [K]', 
               'Rotational speed [rpm]',
                'Torque [Nm]',
                'Tool wear [min]'
                  ]]
targets = df[['TWF',
              'HDF',
              'PWF',
              'OSF',
              'RNF']]

features_sets = {
    "TWF": ['Tool wear [min]', 'Torque [Nm]'],
    "HDF": ['Air temperature [K]', 'Process temperature [K]', 'Rotaional speed [rpm]'],
    "PWF": ['Torque [Nm]', 'Rotational speed [rpm]'],
    "O"
}

# %%
def sigmoid(z):
    return 1/(1+e^(-z))
